# %%
# !wget http://download.magenta.tensorflow.org/datasets/nsynth/nsynth-train.jsonwav.tar.gz
# Out:
# --2026-01-07 03:07:26--  http://download.magenta.tensorflow.org/datasets/nsynth/nsynth-train.jsonwav.tar.gz
# Resolving download.magenta.tensorflow.org (download.magenta.tensorflow.org)... 173.194.195.207, 172.217.214.207, 108.177.121.207, ...
# Connecting to download.magenta.tensorflow.org (download.magenta.tensorflow.org)|173.194.195.207|:80... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 23815298079 (22G) [application/gzip]
# Saving to: ‘nsynth-train.jsonwav.tar.gz’
#
# nsynth-train.jsonwa 100%[===================>]  22.18G   141MB/s    in 4m 46s
#
# 2026-01-07 03:12:12 (79.5 MB/s) - ‘nsynth-train.jsonwav.tar.gz’ saved [23815298079/23815298079]

# %%
# !tar -xvf nsynth-train.jsonwav.tar.gz
# Out:
# Streaming output truncated to the last 5000 lines.
# nsynth-train/audio/organ_electronic_101-070-127.wav
# nsynth-train/audio/organ_electronic_072-049-025.wav
# nsynth-train/audio/organ_electronic_107-079-127.wav
# nsynth-train/audio/reed_acoustic_003-095-127.wav
# nsynth-train/audio/bass_synthetic_114-017-127.wav
# nsynth-train/audio/flute_acoustic_023-107-025.wav
# nsynth-train/audio/bass_synthetic_141-059-050.wav
# nsynth-train/audio/flute_synthetic_001-028-127.wav
# nsynth-train/audio/keyboard_electronic_007-065-100.wav
# nsynth-train/audio/string_acoustic_055-064-100.wav
# nsynth-train/audio/keyboard_synthetic_010-078-050.wav
# nsynth-train/audio/string_acoustic_043-033-050.wav
# nsynth-train/audio/reed_synthetic_001-034-050.wav
# nsynth-train/audio/brass_acoustic_024-031-050.wav
# nsynth-train/audio/bass_synthetic_026-068-050.wav
# nsynth-train/audio/bass_synthetic_076-056-025.wav
# nsynth-train/audio/guitar_acoustic_033-078-127.wav
# ...

# %%
# !python /content/nsynth-train/acoustic-sep.py
# Out:
# Total acoustic files copied: 102165

# %%
# !ls /content/nsynth-train/audio
# Out:
# Streaming output truncated to the last 5000 lines.
# keyboard_electronic_031-072-100.wav  vocal_synthetic_002-094-127.wav
# keyboard_electronic_031-072-127.wav  vocal_synthetic_002-095-025.wav
# keyboard_electronic_031-073-025.wav  vocal_synthetic_002-095-050.wav
# keyboard_electronic_031-073-050.wav  vocal_synthetic_002-095-075.wav
# keyboard_electronic_031-073-075.wav  vocal_synthetic_002-095-100.wav
# keyboard_electronic_031-073-100.wav  vocal_synthetic_002-095-127.wav
# keyboard_electronic_031-073-127.wav  vocal_synthetic_002-096-025.wav
# keyboard_electronic_031-074-025.wav  vocal_synthetic_002-096-050.wav
# keyboard_electronic_031-074-050.wav  vocal_synthetic_002-096-075.wav
# keyboard_electronic_031-074-075.wav  vocal_synthetic_002-096-100.wav
# keyboard_electronic_031-074-100.wav  vocal_synthetic_002-096-127.wav
# keyboard_electronic_031-074-127.wav  vocal_synthetic_002-097-025.wav
# keyboard_electronic_031-075-025.wav  vocal_synthetic_002-097-050.wav
# ...

# %%
# !rm -rf /content/nsynth-acoustic

# %%
# !python /content/nsynth-train/work.py
# Out:
# Found 102165 wav files
#
# Final subset created:
# guitar: 700
# keyboard: 700
# vocal: 700
# string: 700
# reed: 700
# flute: 700
# mallet: 700
# brass: 700

# %%
# !python /content/nsynth-train/preprocess.py
# Out:
# Processing brass: 100% 700/700 [00:34<00:00, 20.44it/s]
# Processing flute: 100% 700/700 [00:12<00:00, 54.38it/s]
# Processing guitar: 100% 700/700 [00:13<00:00, 52.47it/s]
# Processing keyboard: 100% 700/700 [00:15<00:00, 45.47it/s]
# Processing mallet: 100% 700/700 [00:21<00:00, 33.27it/s]
# Processing reed: 100% 700/700 [00:17<00:00, 41.15it/s]
# Processing string: 100% 700/700 [00:14<00:00, 48.23it/s]
# Processing vocal: 100% 700/700 [00:13<00:00, 51.94it/s]
#
# Preprocessing complete!
# X shape: (5600, 128, 128)
# y shape: (5600,)
# Labels: {'brass': 0, 'flute': 1, 'guitar': 2, 'keyboard': 3, 'mallet': 4, 'reed': 5, 'string': 6, 'vocal': 7}
#
# ⚠ Could not save to Drive: 'NoneType' object has no attribute 'kernel'
# Files are still available in /content/Processed

# %%
# !zip -r Processed.zip /content/Processed
from google.colab import files
files.download('/content/Processed.zip')
# Out:
#   adding: content/Processed/ (stored 0%)
#   adding: content/Processed/y.npy (deflated 100%)
#   adding: content/Processed/label_map.json (deflated 34%)
#   adding: content/Processed/X.npy (deflated 52%)
