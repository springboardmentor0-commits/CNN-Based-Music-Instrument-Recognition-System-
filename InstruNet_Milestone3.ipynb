# %% [markdown]
# <a href="https://colab.research.google.com/github/springboardmentor0-commits/CNN-Based-Music-Instrument-Recognition-System-/blob/Prasitha/InstruNet_Milestone3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import os
import numpy as np
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import LabelEncoder
from google.colab import drive

# 1. Mount Google Drive
if not os.path.exists('/content/drive'):
    drive.mount('/content/drive')

# --- CONFIGURATION ---
DATA_PATH = '/content/drive/MyDrive/InstruNet_project/Processed_Data'
IMG_HEIGHT = 128  # Standard Mel-spectrogram height
IMG_WIDTH = 173   # Standard width for ~4 seconds

X = []
y = []

# 2. Load Data Loop
for instrument in os.listdir(DATA_PATH):
    folder_path = os.path.join(DATA_PATH, instrument)

    # Ensure it's a folder
    if os.path.isdir(folder_path):
        print(f"   -> Processing: {instrument}")

        for file in os.listdir(folder_path):
            if file.endswith('.npy'):
                try:
                    # Load file
                    file_path = os.path.join(folder_path, file)
                    data = np.load(file_path)

                    # FORCE SHAPE FIX: Ensure all images are exactly (128, 173)
                    if data.shape[1] > IMG_WIDTH:
                        data = data[:, :IMG_WIDTH] # Crop
                    elif data.shape[1] < IMG_WIDTH:
                        padding = IMG_WIDTH - data.shape[1]
                        data = np.pad(data, ((0,0), (0, padding))) # Pad with zeros

                    X.append(data)
                    y.append(instrument)
                except Exception as e:
                    pass

# 3. Convert to Arrays
X = np.array(X)
y = np.array(y)

# 4. Prepare for CNN (Add Channel Dimension)
# CNNs need input shape: (Height, Width, Channel) -> (128, 173, 1)
X = X[..., np.newaxis]

# 5. Encode Labels (Guitar -> 0, Flute -> 1)
encoder = LabelEncoder()
y_encoded = encoder.fit_transform(y)
class_names = encoder.classes_

# 6. Split Data (80% Train, 20% Test)
X_train, X_test, y_train, y_test = train_test_split(X, y_encoded, test_size=0.2, random_state=42, stratify=y_encoded)

print(f"\n Data Ready! Training on {len(X_train)} samples, Testing on {len(X_test)} samples.")
# Out:
#    -> Processing: bass
#    -> Processing: keyboard
#    -> Processing: guitar
#    -> Processing: reed
#    -> Processing: flute
#    -> Processing: string
#    -> Processing: vocal
#    -> Processing: brass
#    -> Processing: mallet
#    -> Processing: organ
#
#  Data Ready! Training on 3276 samples, Testing on 820 samples.

# %%
import tensorflow as tf
from tensorflow.keras import layers, models
import matplotlib.pyplot as plt

# --- CONFIGURATION ---
# Ensure these match your previous setup
IMG_HEIGHT = 128
IMG_WIDTH = 173
num_classes = len(class_names) # Should be around 10

# --- THE "HIGH PERFORMANCE" MODEL ---
model_perf = models.Sequential([
    # Block 1: The Basics
    layers.Conv2D(32, (3, 3), activation='relu', padding='same', input_shape=(IMG_HEIGHT, IMG_WIDTH, 1)),
    layers.MaxPooling2D((2, 2)),
    layers.BatchNormalization(), # Keeps learning stable

    # Block 2: The Details
    layers.Conv2D(64, (3, 3), activation='relu', padding='same'),
    layers.MaxPooling2D((2, 2)),
    layers.BatchNormalization(),

    # Block 3: The Shapes
    layers.Conv2D(128, (3, 3), activation='relu', padding='same'),
    layers.MaxPooling2D((2, 2)),
    layers.Dropout(0.2), # Light restriction only

    # Block 4: The Complex Features (New Layer for extra power)
    layers.Conv2D(256, (3, 3), activation='relu', padding='same'),
    layers.MaxPooling2D((2, 2)),
    layers.Dropout(0.2),

    layers.Flatten(),

    # Dense Block: The Decision Maker
    layers.Dense(256, activation='relu'),
    layers.Dropout(0.3), # Moderate restriction here

    # Output
    layers.Dense(num_classes, activation='softmax')
])

# Compile with a slightly lower learning rate for precision
model_perf.compile(optimizer=tf.keras.optimizers.Adam(learning_rate=0.0003),
                   loss='sparse_categorical_crossentropy',
                   metrics=['accuracy'])

# Train for longer to ensure we hit the peak
history_perf = model_perf.fit(X_train, y_train,
                              epochs=35,
                              validation_data=(X_test, y_test),
                              batch_size=32)

# --- PLOT THE RESULTS ---
plt.figure(figsize=(12, 5))

# Accuracy
plt.subplot(1, 2, 1)
plt.plot(history_perf.history['accuracy'], label='Train Accuracy')
plt.plot(history_perf.history['val_accuracy'], label='Val Accuracy')
plt.title('Performance Model Accuracy')
plt.legend()
plt.grid(True)

# Loss
plt.subplot(1, 2, 2)
plt.plot(history_perf.history['loss'], label='Train Loss')
plt.plot(history_perf.history['val_loss'], label='Val Loss')
plt.title('Performance Model Loss')
plt.legend()
plt.grid(True)

plt.show()

# Save this one as the final choice
model_perf.save('/content/drive/MyDrive/InstruNet_project/instrunet_best_model.h5')
# Out:
# /usr/local/lib/python3.12/dist-packages/keras/src/layers/convolutional/base_conv.py:113: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# Epoch 1/35
# 103/103 ━━━━━━━━━━━━━━━━━━━━ 24s 128ms/step - accuracy: 0.3724 - loss: 2.1199 - val_accuracy: 0.2732 - val_loss: 2.3085
# Epoch 2/35
# 103/103 ━━━━━━━━━━━━━━━━━━━━ 3s 30ms/step - accuracy: 0.7649 - loss: 0.6181 - val_accuracy: 0.7463 - val_loss: 0.7228
# Epoch 3/35
# 103/103 ━━━━━━━━━━━━━━━━━━━━ 3s 30ms/step - accuracy: 0.9013 - loss: 0.3008 - val_accuracy: 0.8829 - val_loss: 0.3217
# Epoch 4/35
# 103/103 ━━━━━━━━━━━━━━━━━━━━ 3s 31ms/step - accuracy: 0.9414 - loss: 0.1660 - val_accuracy: 0.9378 - val_loss: 0.1781
# Epoch 5/35
# 103/103 ━━━━━━━━━━━━━━━━━━━━ 3s 32ms/step - accuracy: 0.9670 - loss: 0.1156 - val_accuracy: 0.9817 - val_loss: 0.0738
# Epoch 6/35
# 103/103 ━━━━━━━━━━━━━━━━━━━━ 3s 30ms/step - accuracy: 0.9762 - loss: 0.0690 - val_accuracy: 0.9671 - val_loss: 0.0967
# Epoch 7/35
# 103/103 ━━━━━━━━━━━━━━━━━━━━ 3s 30ms/step - accuracy: 0.9820 - loss: 0.0587 - val_accuracy: 0.9927 - val_loss: 0.0352
# Epoch 8/35
# 103/103 ━━━━━━━━━━━━━━━━━━━━ 3s 30ms/step - accuracy: 0.9906 - loss: 0.0342 - val_accuracy: 0.9659 - val_loss: 0.0857
# Epoch 9/35
# 103/103 ━━━━━━━━━━━━━━━━━━━━ 3s 31ms/step - accuracy: 0.9869 - loss: 0.0453 - val_accuracy: 0.9915 - val_loss: 0.0271
# Epoch 10/35
# 103/103 ━━━━━━━━━━━━━━━━━━━━ 3s 31ms/step - accuracy: 0.9926 - loss: 0.0308 - val_accuracy: 0.9878 - val_loss: 0.0371
# Epoch 11/35
# 103/103 ━━━━━━━━━━━━━━━━━━━━ 3s 30ms/step - accuracy: 0.9893 - loss: 0.0464 - val_accuracy: 0.9768 - val_loss: 0.0833
# Epoch 12/35
# 103/103 ━━━━━━━━━━━━━━━━━━━━ 3s 30ms/step - accuracy: 0.9943 - loss: 0.0213 - val_accuracy: 0.9390 - val_loss: 0.1652
# Epoch 13/35
# 103/103 ━━━━━━━━━━━━━━━━━━━━ 3s 31ms/step - accuracy: 0.9932 - loss: 0.0208 - val_accuracy: 0.9915 - val_loss: 0.0265
# Epoch 14/35
# 103/103 ━━━━━━━━━━━━━━━━━━━━ 3s 31ms/step - accuracy: 0.9872 - loss: 0.0416 - val_accuracy: 0.8756 - val_loss: 0.3389
# Epoch 15/35
# 103/103 ━━━━━━━━━━━━━━━━━━━━ 3s 30ms/step - accuracy: 0.9973 - loss: 0.0182 - val_accuracy: 0.9915 - val_loss: 0.0226
# Epoch 16/35
# 103/103 ━━━━━━━━━━━━━━━━━━━━ 3s 30ms/step - accuracy: 0.9963 - loss: 0.0132 - val_accuracy: 0.9915 - val_loss: 0.0251
# Epoch 17/35
# 103/103 ━━━━━━━━━━━━━━━━━━━━ 3s 31ms/step - accuracy: 0.9916 - loss: 0.0255 - val_accuracy: 0.9732 - val_loss: 0.0721
# Epoch 18/35
# 103/103 ━━━━━━━━━━━━━━━━━━━━ 3s 31ms/step - accuracy: 0.9949 - loss: 0.0142 - val_accuracy: 0.9976 - val_loss: 0.0098
# Epoch 19/35
# 103/103 ━━━━━━━━━━━━━━━━━━━━ 3s 30ms/step - accuracy: 0.9964 - loss: 0.0152 - val_accuracy: 0.9951 - val_loss: 0.0223
# Epoch 20/35
# 103/103 ━━━━━━━━━━━━━━━━━━━━ 3s 30ms/step - accuracy: 0.9941 - loss: 0.0202 - val_accuracy: 0.9988 - val_loss: 0.0099
# Epoch 21/35
# 103/103 ━━━━━━━━━━━━━━━━━━━━ 3s 31ms/step - accuracy: 0.9964 - loss: 0.0134 - val_accuracy: 0.9890 - val_loss: 0.0372
# Epoch 22/35
# 103/103 ━━━━━━━━━━━━━━━━━━━━ 3s 32ms/step - accuracy: 0.9911 - loss: 0.0275 - val_accuracy: 0.9585 - val_loss: 0.1282
# Epoch 23/35
# 103/103 ━━━━━━━━━━━━━━━━━━━━ 3s 31ms/step - accuracy: 0.9963 - loss: 0.0137 - val_accuracy: 0.8476 - val_loss: 0.4549
# Epoch 24/35
# 103/103 ━━━━━━━━━━━━━━━━━━━━ 3s 31ms/step - accuracy: 0.9883 - loss: 0.0316 - val_accuracy: 0.9939 - val_loss: 0.0210
# Epoch 25/35
# 103/103 ━━━━━━━━━━━━━━━━━━━━ 3s 32ms/step - accuracy: 0.9964 - loss: 0.0120 - val_accuracy: 0.9427 - val_loss: 0.1567
# Epoch 26/35
# 103/103 ━━━━━━━━━━━━━━━━━━━━ 3s 32ms/step - accuracy: 0.9948 - loss: 0.0139 - val_accuracy: 0.9634 - val_loss: 0.1344
# Epoch 27/35
# 103/103 ━━━━━━━━━━━━━━━━━━━━ 3s 31ms/step - accuracy: 0.9986 - loss: 0.0070 - val_accuracy: 0.9976 - val_loss: 0.0103
# Epoch 28/35
# 103/103 ━━━━━━━━━━━━━━━━━━━━ 3s 31ms/step - accuracy: 0.9938 - loss: 0.0234 - val_accuracy: 0.9610 - val_loss: 0.0931
# Epoch 29/35
# 103/103 ━━━━━━━━━━━━━━━━━━━━ 3s 32ms/step - accuracy: 0.9903 - loss: 0.0275 - val_accuracy: 0.9195 - val_loss: 0.2279
# Epoch 30/35
# 103/103 ━━━━━━━━━━━━━━━━━━━━ 3s 32ms/step - accuracy: 0.9908 - loss: 0.0315 - val_accuracy: 0.5963 - val_loss: 2.6973
# Epoch 31/35
# 103/103 ━━━━━━━━━━━━━━━━━━━━ 3s 31ms/step - accuracy: 0.9866 - loss: 0.0551 - val_accuracy: 0.9890 - val_loss: 0.0342
# Epoch 32/35
# 103/103 ━━━━━━━━━━━━━━━━━━━━ 3s 31ms/step - accuracy: 0.9906 - loss: 0.0370 - val_accuracy: 0.9841 - val_loss: 0.0492
# Epoch 33/35
# 103/103 ━━━━━━━━━━━━━━━━━━━━ 3s 33ms/step - accuracy: 0.9947 - loss: 0.0142 - val_accuracy: 0.9829 - val_loss: 0.0363
# Epoch 34/35
# 103/103 ━━━━━━━━━━━━━━━━━━━━ 3s 32ms/step - accuracy: 0.9944 - loss: 0.0182 - val_accuracy: 0.8854 - val_loss: 0.3723
# Epoch 35/35
# 103/103 ━━━━━━━━━━━━━━━━━━━━ 3s 31ms/step - accuracy: 0.9962 - loss: 0.0085 - val_accuracy: 0.9927 - val_loss: 0.0150
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.

# %%
import tensorflow as tf
import os

# Define the path where we saved the best model
load_path = '/content/drive/MyDrive/InstruNet_project/instrunet_best_model.h5'

# Load it back into the variable 'model'
if os.path.exists(load_path):
    model = tf.keras.models.load_model(load_path)
    print(" Success! Model loaded. You can now run the evaluation code.")
else:
    print("❌ Error: Model file not found. Did you run the training cell?")
# Out:
# WARNING:absl:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
#  Success! Model loaded. You can now run the evaluation code.

# %%
import seaborn as sns
from sklearn.metrics import classification_report, confusion_matrix

# 1. Get Predictions
print("Evaluating Model on Test Data...")
y_pred_probs = model.predict(X_test)
y_pred = np.argmax(y_pred_probs, axis=1)

# 2. Generate NORMALIZED Confusion Matrix (Deliverable #2)
# We normalize over the 'true' conditions (rows) to show percentages
cm = confusion_matrix(y_test, y_pred)
cm_normalized = cm.astype('float') / cm.sum(axis=1)[:, np.newaxis]

plt.figure(figsize=(10, 8))
sns.heatmap(cm_normalized, annot=True, fmt='.2f', cmap='Greens',
            xticklabels=class_names,
            yticklabels=class_names)
plt.xlabel('Predicted Label')
plt.ylabel('True Label')
plt.title('Normalized Confusion Matrix (Accuracy %)')
plt.show()

# 3. Text Report (Deliverable #3)
print("\nClassification Report:\n")
print(classification_report(y_test, y_pred, target_names=class_names))

# 4. Save the Model
save_path = '/content/drive/MyDrive/InstruNet_project/instrunet_best_model.h5'
model.save(save_path)
print(f"\nSuccess! Model saved to: {save_path}")
# Out:
# Evaluating Model on Test Data...
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 1s 29ms/step
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# Classification Report:
#
#               precision    recall  f1-score   support
#
#         bass       0.98      1.00      0.99       169
#        brass       1.00      1.00      1.00        54
#        flute       1.00      1.00      1.00        36
#       guitar       0.98      0.99      0.99       131
#     keyboard       0.99      0.99      0.99       153
#       mallet       1.00      0.93      0.96        40
#        organ       1.00      1.00      1.00       101
#         reed       1.00      1.00      1.00        47
#       string       1.00      0.98      0.99        61
#        vocal       1.00      1.00      1.00        28
#
#     accuracy                           0.99       820
#    macro avg       1.00      0.99      0.99       820
# weighted avg       0.99      0.99      0.99       820
#
#
# Success! Model saved to: /content/drive/MyDrive/InstruNet_project/instrunet_best_model.h5

# %%
import numpy as np
import librosa
import librosa.display
import tensorflow as tf
import matplotlib.pyplot as plt
import os

# --- 1. CONFIGURATION ---
# 👉 PUT YOUR FILE PATH HERE:
AUDIO_FILE_PATH = '/content/flute_synthetic_000-034-075.wav'

MODEL_PATH = '/content/drive/MyDrive/InstruNet_project/instrunet_best_model.h5'
IMG_WIDTH = 173
CLASSES = ['bass', 'brass', 'flute', 'guitar', 'keyboard', 'mallet', 'organ', 'reed', 'string', 'vocal']

# --- 2. LOAD MODEL ---
if os.path.exists(MODEL_PATH):
    print(f" Loading model from {MODEL_PATH}...")
    model = tf.keras.models.load_model(MODEL_PATH)
    print("Model Loaded!")
else:
    print("Error: Model file not found. Check the path!")
    exit()

# --- 3. PREDICTION FUNCTION ---
def predict_instrument(file_path):
    if not os.path.exists(file_path):
        print(f" Error: Audio file not found at {file_path}")
        return

    print(f"\n Analyzing: {os.path.basename(file_path)} ...")

    # A. Load Audio
    y, sr = librosa.load(file_path, sr=22050, mono=True)

    # B. Fix Duration (4 seconds)
    max_len = 22050 * 4
    if len(y) > max_len:
        y = y[:max_len]
    else:
        y = np.pad(y, (0, max_len - len(y)))

    # C. Create Spectrogram
    spec = librosa.feature.melspectrogram(y=y, sr=sr, n_mels=128)
    log_spec = librosa.power_to_db(spec, ref=np.max)

    # D. Resize (173 width)
    if log_spec.shape[1] > IMG_WIDTH:
        log_spec = log_spec[:, :IMG_WIDTH]
    else:
        padding = IMG_WIDTH - log_spec.shape[1]
        log_spec = np.pad(log_spec, ((0,0), (0, padding)))

    # E. Reshape for Model
    input_data = log_spec[..., np.newaxis][np.newaxis, ...]

    # F. Predict
    preds = model.predict(input_data)
    pred_idx = np.argmax(preds)
    pred_label = CLASSES[pred_idx]
    confidence = np.max(preds) * 100

    # --- 4. SHOW RESULTS ---
    print(f"\nPREDICTED INSTRUMENT: {pred_label.upper()}")
    print(f"CONFIDENCE: {confidence:.2f}%")

    # Show Graph
    plt.figure(figsize=(10, 4))

    # Spectrogram
    plt.subplot(1, 2, 1)
    librosa.display.specshow(log_spec, sr=sr, x_axis='time', y_axis='mel')
    plt.title(f"Spectrogram")
    plt.colorbar(format='%+2.0f dB')

    # Probability Bar Chart
    plt.subplot(1, 2, 2)
    plt.bar(CLASSES, preds[0], color='skyblue')
    plt.xticks(rotation=45)
    plt.title("Confidence Scores")

    plt.tight_layout()
    plt.show()

# --- 5. RUN IT ---
predict_instrument(AUDIO_FILE_PATH)
# Out:
#  Loading model from /content/drive/MyDrive/InstruNet_project/instrunet_best_model.h5...
# WARNING:absl:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# Model Loaded!
#
#  Analyzing: flute_synthetic_000-034-075.wav ...
# WARNING:tensorflow:5 out of the last 29 calls to <function TensorFlowTrainer.make_predict_function.<locals>.one_step_on_data_distributed at 0x7b77e211b100> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has reduce_retracing=True option that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step
#
# PREDICTED INSTRUMENT: FLUTE
# CONFIDENCE: 91.29%
